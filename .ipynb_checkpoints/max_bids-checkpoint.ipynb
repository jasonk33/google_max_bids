# %%
import numpy as np
import pandas as pd
import warnings
import pycountry
warnings.filterwarnings(action="ignore")
pd.options.display.max_colwidth = 200
pd.set_option('display.max_columns', 30)
# %load_ext autotime

# %%
def get_country_from_ISO(iso_code):
    try:
        return pycountry.countries.get(alpha_2=iso_code).name
    except:
        return ""
# Out:
# time: 1.53 ms

# %%
output_df = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - Google Ads - 1 Day.csv", skiprows=2)[['Campaign', 'Ad group', "Ad group max. CPV"]]
output_df["Country"] = output_df['Campaign'].str.split("|", expand=True)[2].str.strip()
# Out:
# time: 500 ms

# %%
for day in [1, 7, 14, 30]:
    google = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - Google Ads - {} Day.csv".format(day), 
                           skiprows=2)[['Campaign', 'Ad group', "YouTube Earned Views", "Views"]]
    output_df = output_df.merge(google, on=["Campaign", "Ad group"]).rename(columns={"YouTube Earned Views": 
                                                                                       "YouTube Earned Views {} days".format(day), 
                                                                                     'Views': "Ad Views {} days".format(day)})
# Out:
# time: 702 ms

# %%
for day in [1, 7, 14, 30]:
    youtube = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - YouTube - {} Day.csv".format(day))
    google = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - Google Ads - {} Day.csv".format(day), skiprows=2)
    google["Country"] = google['Campaign'].str.split("|", expand=True)[2].str.strip()
    google['Cost'] *= 0.055
    google['Ad group max. CPV'] *= 0.055
    google['Avg. CPV'] *= 0.055
    google_ads_country_groups = google.groupby("Country").sum().reset_index()
    youtube['Country'] = youtube['Geography'].apply(get_country_from_ISO)
    combined_df_country_groups = google_ads_country_groups.merge(youtube, on="Country", how="left", suffixes=("_Google", "_Youtube"))
    combined_df_country_groups["Country ROAS {} days".format(day)] = combined_df_country_groups['Your estimated revenue (USD)']/combined_df_country_groups['Cost']
    df = combined_df_country_groups[['Country', 'Cost', 'Views_Google', 'YouTube Earned Views', 'Your estimated revenue (USD)', "Country ROAS {} days".format(day)]]
    df["Earned View Value {} days".format(day)] = df['Your estimated revenue (USD)']/df['YouTube Earned Views']
    output_df = output_df.merge(df[["Country", "Earned View Value {} days".format(day), 
                                    "Country ROAS {} days".format(day)]], on="Country", how="left")
    output_df = output_df.merge(google[['Campaign', 'Ad group', 'Cost']], on=["Campaign", "Ad group"], how="left").rename(columns={"Cost": "Cost {} day".format(day)})
    output_df["Earned View Cost {} days".format(day)] = output_df["Cost {} day".format(day)]/output_df["YouTube Earned Views {} days".format(day)]
# Out:
# time: 1.35 s

# %%
def calculate_max_bid(row):
    standard_weights = {1: .4, 7: .3, 14: .2, 30: .1}
    adjusted_weights = standard_weights.copy()
    minimum_number_views = 10
    type_of_view = "Ad Views"
    for day in [1, 7, 14, 30]:
        if row["{} {} days".format(type_of_view, day)] < minimum_number_views:
            adjusted_weights[day] = 0
    total_weight = np.sum(list(adjusted_weights.values()))
    if total_weight == 0:
        return row['Ad group max. CPV']
    country_ROAS = 0
    earned_view_value_over_cost = 0
    for day in [1, 7, 14, 30]:
        adjusted_weights[day] /= total_weight
        country_ROAS += row["Country ROAS {} days".format(day)] * standard_weights[day]
        earned_view_value_over_cost += ((row["Earned View Value {} days".format(day)]) / (row["Earned View Cost {} days".format(day)])) * adjusted_weights[day]
        
    if (earned_view_value_over_cost >= 1) or (country_ROAS >= 2):
        return row['Ad group max. CPV'] * 1.1
    elif earned_view_value_over_cost <= .5:
        return row['Ad group max. CPV'] * 0.9
    else:
        return row['Ad group max. CPV']
# Out:
# time: 3.21 ms

# %%
output_df["Max Bid"] = output_df.apply(calculate_max_bid, axis=1)
# Out:
# time: 3.58 s

# %%
output_df[output_df['Max Bid'] != output_df['Ad group max. CPV']]
# Out:
#                                   Campaign  \
# 1292    92 Keys | YouTube | Italy | Search
# 1629   92 Keys | YouTube | Mexico | Search
# 2669   92 Keys | YouTube | Sweden | Search
# 3576    92 Keys | YouTube | Spain | Search
# 3579    92 Keys | YouTube | Spain | Search
# ...                                    ...
# 39853  92 Keys | YouTube | Israel | Videos
# 39855  92 Keys | YouTube | Israel | Videos
# 39857  92 Keys | YouTube | Israel | Videos
# 39863  92 Keys | YouTube | Israel | Videos
# 39918  92 Keys | YouTube | Israel | Videos
#
#                                                                                    Ad group  \
# 1292                   Christmas Bumper | Affinity | Classical Fans | Mobile | 55-64 | Male
# 1629   Christmas Bumper | Affinity | Classical Fans | Mobile | Unknown Age | Unknown Gender
# 2669           Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 45-54 | Male
# 3576                 Christmas Bumper | Affinity | Classical Fans | Mobile | 25-34 | Female
# 3579                   Christmas Bumper | Affinity | Classical Fans | Mobile | 35-44 | Male
# ...                                                                                     ...
# 39853          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 45-54 | Male
# 39855          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 55-64 | Male
# 39857          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 65+ | Female
# 39863          Carol of the Bells Audio | Affinity | Classical Fans | Tablet | 45-54 | Male
# 39918                  Christmas Bumper | Affinity | Classical Fans | Mobile | 65+ | Female
#
#        Ad group max. CPV Country  YouTube Earned Views 1 days  \
# 1292                0.03   Italy                            9
# 1629                0.03  Mexico                           10
# 2669                0.14  Sweden                            0
# 3576                0.05   Spain                            2
# 3579                0.05   Spain                            2
# ...                  ...     ...                          ...
# 39853               0.08  Israel                            0
# 39855               0.08  Israel                            0
# 39857               0.08  Israel                            0
# 39863               0.08  Israel                            0
# 39918               0.08  Israel                            2
#
#        Ad Views 1 days  YouTube Earned Views 7 days  Ad Views 7 days  \
# 1292                37                            9               37
# 1629                24                           11               25
# 2669                12                            0               12
# 3576                22                            2               22
# 3579                30                            2               30
# ...                ...                          ...              ...
# 39853                7                            0               16
# 39855                4                            0               11
# 39857                3                            1               11
# 39863                5                            0                9
# 39918                8                            2               16
#
#        YouTube Earned Views 14 days  Ad Views 14 days  \
# 1292                              9                37
# 1629                             11                25
# 2669                              0                12
# 3576                              2                22
# 3579                              2                30
# ...                             ...               ...
# 39853                             0                16
# 39855                             0                11
# 39857                             1                11
# 39863                             0                 9
# 39918                             2                16
#
#        YouTube Earned Views 30 days  Ad Views 30 days  \
# 1292                              9                37
# 1629                             11                25
# 2669                              0                12
# 3576                              2                22
# 3579                              2                30
# ...                             ...               ...
# 39853                             0                21
# 39855                             0                13
# 39857                             1                11
# 39863                             0                10
# 39918                             2                18
#
#        Earned View Value 1 days  Country ROAS 1 days  Cost 1 day  \
# 1292                   0.002688             0.370823     0.03575
# 1629                   0.001590             0.271604     0.01980
# 2669                   0.007763             0.202020     0.04675
# 3576                   0.002839             0.334209     0.03575
# 3579                   0.002839             0.334209     0.05445
# ...                         ...                  ...         ...
# 39853                  0.003333             0.141343     0.02915
# 39855                  0.003333             0.141343     0.01540
# 39857                  0.003333             0.141343     0.01155
# 39863                  0.003333             0.141343     0.01980
# 39918                  0.003333             0.141343     0.03025
#
#        Earned View Cost 1 days  Earned View Value 7 days  Country ROAS 7 days  \
# 1292                  0.003972                  0.003949             0.548003
# 1629                  0.001980                  0.001410             0.207296
# 2669                       inf                  0.009348             0.175374
# 3576                  0.017875                  0.003167             0.366479
# 3579                  0.027225                  0.003167             0.366479
# ...                        ...                       ...                  ...
# 39853                      inf                  0.003575             0.118505
# 39855                      inf                  0.003575             0.118505
# 39857                      inf                  0.003575             0.118505
# 39863                      inf                  0.003575             0.118505
# 39918                 0.015125                  0.003575             0.118505
#
#        Cost 7 day  Earned View Cost 7 days  Earned View Value 14 days  \
# 1292      0.03575                 0.003972                   0.010194
# 1629      0.02090                 0.001900                   0.001990
# 2669      0.04675                      inf                   0.015370
# 3576      0.03575                 0.017875                   0.005000
# 3579      0.05445                 0.027225                   0.005000
# ...           ...                      ...                        ...
# 39853     0.06105                      inf                   0.007525
# 39855     0.04180                      inf                   0.007525
# 39857     0.04180                 0.041800                   0.007525
# 39863     0.03575                      inf                   0.007525
# 39918     0.05775                 0.028875                   0.007525
#
#        Country ROAS 14 days  Cost 14 day  Earned View Cost 14 days  \
# 1292               1.414613      0.03575                  0.003972
# 1629               0.292695      0.02090                  0.001900
# 2669               0.288348      0.04675                       inf
# 3576               0.578651      0.03575                  0.017875
# 3579               0.578651      0.05445                  0.027225
# ...                     ...          ...                       ...
# 39853              0.249441      0.06105                       inf
# 39855              0.249441      0.04180                       inf
# 39857              0.249441      0.04180                  0.041800
# 39863              0.249441      0.03575                       inf
# 39918              0.249441      0.05775                  0.028875
#
#        Earned View Value 30 days  Country ROAS 30 days  Cost 30 day  \
# 1292                    0.025520              3.527752      0.03575
# 1629                    0.009346              1.331339      0.02090
# 2669                    0.060152              1.028816      0.04675
# 3576                    0.030386              3.452951      0.03575
# 3579                    0.030386              3.452951      0.05445
# ...                          ...                   ...          ...
# 39853                   0.025122              0.763444      0.08030
# 39855                   0.025122              0.763444      0.04950
# 39857                   0.025122              0.763444      0.04180
# 39863                   0.025122              0.763444      0.04015
# 39918                   0.025122              0.763444      0.06490
#
#        Earned View Cost 30 days  Max Bid
# 1292                   0.003972    0.033
# 1629                   0.001900    0.033
# 2669                        inf    0.126
# 3576                   0.017875    0.045
# 3579                   0.027225    0.045
# ...                         ...      ...
# 39853                       inf    0.072
# 39855                       inf    0.072
# 39857                  0.041800    0.072
# 39863                       inf    0.072
# 39918                  0.032450    0.072
#
# [107 rows x 29 columns]
# time: 53.8 ms

# %%
new_max_bid_df = output_df[output_df['Max Bid'] != output_df['Ad group max. CPV']][['Campaign', 'Ad group', 'Max Bid']].round(3)
# Out:
# time: 13.7 ms

# %%
new_max_bid_df
# Out:
#                                   Campaign  \
# 1292    92 Keys | YouTube | Italy | Search
# 1629   92 Keys | YouTube | Mexico | Search
# 2669   92 Keys | YouTube | Sweden | Search
# 3576    92 Keys | YouTube | Spain | Search
# 3579    92 Keys | YouTube | Spain | Search
# ...                                    ...
# 39853  92 Keys | YouTube | Israel | Videos
# 39855  92 Keys | YouTube | Israel | Videos
# 39857  92 Keys | YouTube | Israel | Videos
# 39863  92 Keys | YouTube | Israel | Videos
# 39918  92 Keys | YouTube | Israel | Videos
#
#                                                                                    Ad group  \
# 1292                   Christmas Bumper | Affinity | Classical Fans | Mobile | 55-64 | Male
# 1629   Christmas Bumper | Affinity | Classical Fans | Mobile | Unknown Age | Unknown Gender
# 2669           Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 45-54 | Male
# 3576                 Christmas Bumper | Affinity | Classical Fans | Mobile | 25-34 | Female
# 3579                   Christmas Bumper | Affinity | Classical Fans | Mobile | 35-44 | Male
# ...                                                                                     ...
# 39853          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 45-54 | Male
# 39855          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 55-64 | Male
# 39857          Carol of the Bells Audio | Affinity | Classical Fans | Mobile | 65+ | Female
# 39863          Carol of the Bells Audio | Affinity | Classical Fans | Tablet | 45-54 | Male
# 39918                  Christmas Bumper | Affinity | Classical Fans | Mobile | 65+ | Female
#
#        Max Bid
# 1292     0.033
# 1629     0.033
# 2669     0.126
# 3576     0.045
# 3579     0.045
# ...        ...
# 39853    0.072
# 39855    0.072
# 39857    0.072
# 39863    0.072
# 39918    0.072
#
# [107 rows x 3 columns]
# time: 17.3 ms

# %%
new_max_bid_df.to_csv("new_max_bid_ads.csv", index=False)
# Out:
# time: 19.1 ms

# %%
dfs[3]
# Out:
#            Country     Cost  Views_Google  YouTube Earned Views  \
# 0        Australia  1.23640           199                    16
# 1          Austria  0.83325           318                    30
# 2          Belgium  0.02310             9                     2
# 3           Canada  1.90245           264                    31
# 4          Czechia  1.24190           369                    42
# 5          Denmark  0.09625            26                     4
# 6          Finland  0.01980             6                     1
# 7           France  1.05765           299                    33
# 8          Germany  1.35520           264                    36
# 9        Hong Kong  0.35090           116                    21
# 10         Iceland  0.07645            21                     3
# 11         Ireland  0.13365            44                     2
# 12          Israel  1.34915           393                    41
# 13           Italy  0.70895           729                    98
# 14      Luxembourg  0.00385             1                     0
# 15          Mexico  2.94140          2564                   419
# 16     Netherlands  0.23375            73                     8
# 17     New Zealand  0.03960            15                     3
# 18          Norway  0.08085            28                     1
# 19        Portugal  0.32890           215                    38
# 20       Singapore  0.33935           107                    10
# 21     South Korea  1.53065           388                    40
# 22           Spain  1.00320           592                   114
# 23          Sweden  2.68950           498                    46
# 24     Switzerland  2.74340           344                    24
# 25  United Kingdom  2.06250           365                    23
# 26   United States  1.25180           192                    33
#
#     Your estimated revenue (USD)    ROAS_30  Earned View Value 30 days
# 0                          2.094   1.693627                   0.130875
# 1                          2.455   2.946295                   0.081833
# 2                          1.204  52.121212                   0.602000
# 3                          7.915   4.160425                   0.255323
# 4                          2.064   1.661970                   0.049143
# 5                          0.997  10.358442                   0.249250
# 6                          0.246  12.424242                   0.246000
# 7                          2.999   2.835532                   0.090879
# 8                          4.314   3.183294                   0.119833
# 9                          1.135   3.234540                   0.054048
# 10                         0.118   1.543492                   0.039333
# 11                         0.609   4.556678                   0.304500
# 12                         1.030   0.763444                   0.025122
# 13                         2.501   3.527752                   0.025520
# 14                         0.212  55.064935                        inf
# 15                         3.916   1.331339                   0.009346
# 16                         2.249   9.621390                   0.281125
# 17                         0.332   8.383838                   0.110667
# 18                         0.454   5.615337                   0.454000
# 19                         0.937   2.848890                   0.024658
# 20                         1.629   4.800354                   0.162900
# 21                           NaN        NaN                        NaN
# 22                         3.464   3.452951                   0.030386
# 23                         2.767   1.028816                   0.060152
# 24                         6.393   2.330320                   0.266375
# 25                         4.221   2.046545                   0.183522
# 26                        32.208  25.729350                   0.976000
# time: 18.9 ms

# %%
youtube_30_day = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - YouTube - 30 Day.csv")
google_30_day = pd.read_csv("120719 - 92 Keys/120719 - 92 Keys - Google Ads - 30 Day.csv", skiprows=2)
# Out:
# time: 159 ms

# %%
google_30_day["Country"] = google_30_day['Campaign'].str.split("|", expand=True)[2].str.strip()
# Out:
# time: 228 ms

# %%
google_30_day['Cost'] *= 0.055
# Out:
# time: 4.78 ms

# %%
google_ads_country_groups = google_30_day.groupby("Country").sum().reset_index()
# Out:
# time: 35.8 ms

# %%
combined_df_country_groups = google_ads_country_groups.merge(youtube_30_day, on="Country", how="left", suffixes=("_Google", "_Youtube"))
# Out:
# time: 11.5 ms

# %%
combined_df_country_groups['ROAS'] = combined_df_country_groups['Your estimated revenue (USD)']/combined_df_country_groups['Cost']
# Out:
# time: 1.56 ms

# %%
df = combined_df_country_groups[['Country', 'Cost', 'Views_Google', 'YouTube Earned Views', 'Your estimated revenue (USD)', 'ROAS']]
# Out:
# time: 4.18 ms

# %%
df['Earned View Value 30 days'] = df['Your estimated revenue (USD)']/df['YouTube Earned Views']
# Out:
# time: 3.62 ms

# %%
df
# Out:
#            Country     Cost  Views_Google  YouTube Earned Views  \
# 0        Australia  1.23640           199                    16
# 1          Austria  0.83325           318                    30
# 2          Belgium  0.02310             9                     2
# 3           Canada  1.90245           264                    31
# 4          Czechia  1.24190           369                    42
# 5          Denmark  0.09625            26                     4
# 6          Finland  0.01980             6                     1
# 7           France  1.05765           299                    33
# 8          Germany  1.35520           264                    36
# 9        Hong Kong  0.35090           116                    21
# 10         Iceland  0.07645            21                     3
# 11         Ireland  0.13365            44                     2
# 12          Israel  1.34915           393                    41
# 13           Italy  0.70895           729                    98
# 14      Luxembourg  0.00385             1                     0
# 15          Mexico  2.94140          2564                   419
# 16     Netherlands  0.23375            73                     8
# 17     New Zealand  0.03960            15                     3
# 18          Norway  0.08085            28                     1
# 19        Portugal  0.32890           215                    38
# 20       Singapore  0.33935           107                    10
# 21     South Korea  1.53065           388                    40
# 22           Spain  1.00320           592                   114
# 23          Sweden  2.68950           498                    46
# 24     Switzerland  2.74340           344                    24
# 25  United Kingdom  2.06250           365                    23
# 26   United States  1.25180           192                    33
#
#     Your estimated revenue (USD)       ROAS  Earned View Value 30 days
# 0                          2.094   1.693627                   0.130875
# 1                          2.455   2.946295                   0.081833
# 2                          1.204  52.121212                   0.602000
# 3                          7.915   4.160425                   0.255323
# 4                          2.064   1.661970                   0.049143
# 5                          0.997  10.358442                   0.249250
# 6                          0.246  12.424242                   0.246000
# 7                          2.999   2.835532                   0.090879
# 8                          4.314   3.183294                   0.119833
# 9                          1.135   3.234540                   0.054048
# 10                         0.118   1.543492                   0.039333
# 11                         0.609   4.556678                   0.304500
# 12                         1.030   0.763444                   0.025122
# 13                         2.501   3.527752                   0.025520
# 14                         0.212  55.064935                        inf
# 15                         3.916   1.331339                   0.009346
# 16                         2.249   9.621390                   0.281125
# 17                         0.332   8.383838                   0.110667
# 18                         0.454   5.615337                   0.454000
# 19                         0.937   2.848890                   0.024658
# 20                         1.629   4.800354                   0.162900
# 21                           NaN        NaN                        NaN
# 22                         3.464   3.452951                   0.030386
# 23                         2.767   1.028816                   0.060152
# 24                         6.393   2.330320                   0.266375
# 25                         4.221   2.046545                   0.183522
# 26                        32.208  25.729350                   0.976000
# time: 17.4 ms

# %%
google_30_day.merge(df, on="Country", how="left")
# Out:
#                                     Campaign  \
# 0      92 Keys | YouTube | Portugal | Videos
# 1      92 Keys | YouTube | Portugal | Videos
# 2      92 Keys | YouTube | Portugal | Videos
# 3      92 Keys | YouTube | Portugal | Videos
# 4      92 Keys | YouTube | Portugal | Videos
# ...                                      ...
# 40819   92 Keys | YouTube | Belgium | Search
# 40820   92 Keys | YouTube | Belgium | Search
# 40821   92 Keys | YouTube | Belgium | Search
# 40822   92 Keys | YouTube | Belgium | Search
# 40823   92 Keys | YouTube | Belgium | Search
#
#                                                 Ad group  Ad group status  \
# 0      Christmas Bumper | Topics | Religious Music | ...  Campaign paused
# 1      Christmas Bumper | Affinity | Classical Fans |...  Campaign paused
# 2      Christmas Bumper | Affinity | Classical Fans |...  Campaign paused
# 3      Christmas Bumper | Affinity | Classical Fans |...  Campaign paused
# 4      Christmas Bumper | Affinity | Classical Fans |...  Campaign paused
# ...                                                  ...              ...
# 40819  Christmas Bumper | Topics | Classical Music | ...  Campaign paused
# 40820  Christmas Bumper | Topics | Classical Music | ...  Campaign paused
# 40821  Christmas Bumper | Topics | Classical Music | ...  Campaign paused
# 40822  Christmas Bumper | Topics | Classical Music | ...  Campaign paused
# 40823  Christmas Bumper | Topics | Religious Music | ...  Campaign paused
#
#        Ad group max. CPV Currency Impressions View rate  Cost_x  Avg. CPV  \
# 0                   0.04      MXN           0     0.00%     0.0       0.0
# 1                   0.04      MXN           0     0.00%     0.0       0.0
# 2                   0.04      MXN           0     0.00%     0.0       0.0
# 3                   0.04      MXN           0     0.00%     0.0       0.0
# 4                   0.04      MXN           0     0.00%     0.0       0.0
# ...                  ...      ...         ...       ...     ...       ...
# 40819               0.08      MXN           0     0.00%     0.0       0.0
# 40820               0.08      MXN           0     0.00%     0.0       0.0
# 40821               0.08      MXN           0     0.00%     0.0       0.0
# 40822               0.08      MXN           0     0.00%     0.0       0.0
# 40823               0.08      MXN           0     0.00%     0.0       0.0
#
#        Views  YouTube Earned Views_x   Country  Cost_y  Views_Google  \
# 0          0                       0  Portugal  0.3289           215
# 1          0                       0  Portugal  0.3289           215
# 2          0                       0  Portugal  0.3289           215
# 3          0                       0  Portugal  0.3289           215
# 4          0                       0  Portugal  0.3289           215
# ...      ...                     ...       ...     ...           ...
# 40819      0                       0   Belgium  0.0231             9
# 40820      0                       0   Belgium  0.0231             9
# 40821      0                       0   Belgium  0.0231             9
# 40822      0                       0   Belgium  0.0231             9
# 40823      0                       0   Belgium  0.0231             9
#
#        YouTube Earned Views_y  Your estimated revenue (USD)      ROAS  \
# 0                          38                         0.937  0.351014
# 1                          38                         0.937  0.351014
# 2                          38                         0.937  0.351014
# 3                          38                         0.937  0.351014
# 4                          38                         0.937  0.351014
# ...                       ...                           ...       ...
# 40819                       2                         1.204  0.019186
# 40820                       2                         1.204  0.019186
# 40821                       2                         1.204  0.019186
# 40822                       2                         1.204  0.019186
# 40823                       2                         1.204  0.019186
#
#        Earned View Value 30 days
# 0                       0.024658
# 1                       0.024658
# 2                       0.024658
# 3                       0.024658
# 4                       0.024658
# ...                          ...
# 40819                   0.602000
# 40820                   0.602000
# 40821                   0.602000
# 40822                   0.602000
# 40823                   0.602000
#
# [40824 rows x 18 columns]
# time: 92.7 ms

# %%
df
# Out:
#            Country     Cost  Views_Google  YouTube Earned Views  \
# 0        Australia  1.23640           199                    16
# 1          Austria  0.83325           318                    30
# 2          Belgium  0.02310             9                     2
# 3           Canada  1.90245           264                    31
# 4          Czechia  1.24190           369                    42
# 5          Denmark  0.09625            26                     4
# 6          Finland  0.01980             6                     1
# 7           France  1.05765           299                    33
# 8          Germany  1.35520           264                    36
# 9        Hong Kong  0.35090           116                    21
# 10         Iceland  0.07645            21                     3
# 11         Ireland  0.13365            44                     2
# 12          Israel  1.34915           393                    41
# 13           Italy  0.70895           729                    98
# 14      Luxembourg  0.00385             1                     0
# 15          Mexico  2.94140          2564                   419
# 16     Netherlands  0.23375            73                     8
# 17     New Zealand  0.03960            15                     3
# 18          Norway  0.08085            28                     1
# 19        Portugal  0.32890           215                    38
# 20       Singapore  0.33935           107                    10
# 21     South Korea  1.53065           388                    40
# 22           Spain  1.00320           592                   114
# 23          Sweden  2.68950           498                    46
# 24     Switzerland  2.74340           344                    24
# 25  United Kingdom  2.06250           365                    23
# 26   United States  1.25180           192                    33
#
#     Your estimated revenue (USD)      ROAS  Earned View Value
# 0                          2.094  0.590449           0.130875
# 1                          2.455  0.339409           0.081833
# 2                          1.204  0.019186           0.602000
# 3                          7.915  0.240360           0.255323
# 4                          2.064  0.601696           0.049143
# 5                          0.997  0.096540           0.249250
# 6                          0.246  0.080488           0.246000
# 7                          2.999  0.352668           0.090879
# 8                          4.314  0.314140           0.119833
# 9                          1.135  0.309163           0.054048
# 10                         0.118  0.647881           0.039333
# 11                         0.609  0.219458           0.304500
# 12                         1.030  1.309854           0.025122
# 13                         2.501  0.283467           0.025520
# 14                         0.212  0.018160                inf
# 15                         3.916  0.751124           0.009346
# 16                         2.249  0.103935           0.281125
# 17                         0.332  0.119277           0.110667
# 18                         0.454  0.178084           0.454000
# 19                         0.937  0.351014           0.024658
# 20                         1.629  0.208318           0.162900
# 21                           NaN       NaN                NaN
# 22                         3.464  0.289607           0.030386
# 23                         2.767  0.971991           0.060152
# 24                         6.393  0.429126           0.266375
# 25                         4.221  0.488628           0.183522
# 26                        32.208  0.038866           0.976000
# time: 29.2 ms

# %%
earned_view_by_country_1_day = google_1_day.groupby("Country").sum()[['YouTube Earned Views']].reset_index().sort_values("YouTube Earned Views", ascending=False).reset_index(drop=True)
